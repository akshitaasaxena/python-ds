# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitaasaxena/python-ds/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %%
lst = [1, 2, 3, "akshita", "saxena", 'c', [2,4]]
print (lst)
# Out:
# [1, 2, 3, 'akshita', 'saxena', 'c', [2, 4]]

# %%
lst = [1, 2, 3, "akshita", "saxena", 'c', [2,4]]
lst.append('hello')
print (lst)

lst.append([12,13,14])
print (lst)
# Out:
# [1, 2, 3, 'akshita', 'saxena', 'c', [2, 4], 'hello']
# [1, 2, 3, 'akshita', 'saxena', 'c', [2, 4], 'hello', [12, 13, 14]]

# %%
lst = [1, 2, 3, "jiya", "kaushik", 'c', [2,4]]
lst.extend([12,13,14])
print (lst)

# %%
lst = [1, 2, 3, "jiya", "kaushik", 'c', [2,4]]
# lst.insert(index,value)

lst.insert(2, "value")
print(lst)

# %%
lst2=["hi", "jiya", 3, [9,8,10]]

# to extend at last->
lst2.extend({'akshita':78})
print(lst2)

# to add at last->
lst2.append({5,6})
print(lst2)

#to insert in between->
lst2.insert(4,{'sun':3})
print(lst2)
# Out:
# ['hi', 'jiya', 3, [9, 8, 10], 'akshita']
# ['hi', 'jiya', 3, [9, 8, 10], 'akshita', {5, 6}]
# ['hi', 'jiya', 3, [9, 8, 10], {'sun': 3}, 'akshita', {5, 6}]

# %%
lst = [1, 2, 3, "akshita", "saxena", 'c', [2,4]]
lst.pop()
print(lst)
# Out:
# [1, 2, 3, 'jiya', 'kaushik', 'c']

# %%
lst = [1, 2, 3, "jiya", 2, "kaushik", 'c', [2,4]]
lst.remove(2)
print(lst)
# Out:
# [1, 3, 'jiya', 2, 'kaushik', 'c', [2, 4]]

# %%
lst = [1, 2, 3, "jiya", 2, "kaushik", 'c', [2,4]]
print(lst.index(2))
# Out:
# 1

# %%
lst = [1, 2, 3, "jiya", 2, "kaushik", 'c', [2,4]]
print(lst.count(2))
# Out:
# 2

# %%
lst = [23,100,4,67,12]
lst.sort()
print(lst)
# Out:
# [4, 12, 23, 67, 100]

# %%
lst = [23,100,4,67,12]
a= sorted(lst)
print(a)
type(a)
# Out:
# [4, 12, 23, 67, 100]
# list

# %%
lst = [23,100,4,67,12]
a=sum(lst)
print(a)
# Out:
# 206

# %%
tp=(1,2,3,4)
print(tp)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# since we cannot change or modify tuples there is no add, append, remove, pop functions
#
# We cannot use sort as well because it will change the order
#
# it will try to change in the same tuple which tuple wont allow
#
# Sorted -> can be used in tuple because ut returns a new list
#
# it will not modify anything in the tuple

# %%
tp=(5,7,1,2)
sorted(tp)
# Out:
# [1, 2, 5, 7]

# %%
tp=(5,7,1,2)
a = tuple(sorted(tp))
print (a)
# Out:
# (1, 2, 5, 7)

# %%
tp=(5,7,1,2,10,1)
tp.count(1)
# Out:
# 2

# %%
tp=(5,7,1,2,10,1)
len(tp)
# Out:
# 6

# %%
tp=(5,7,1,2,10,1)
a=sum(tp)
print(a)
# Out:
# 26

# %%
lst1=[]
for i in range (0,3):
  a=int(input())
  lst1.append(a)

lst2=[]
for i in range (0,3):
  a=int(input())
  lst2.append(a)
lst3=[]
for i in range (0,3):
  lst3.append(lst1[i]+lst2[i])
print(lst3)
# Out:
# 3
# 4
# 5
# 5
# 6
# 7
# [8, 10, 12]
