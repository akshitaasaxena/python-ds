# %% [markdown]
# <a href="https://colab.research.google.com/github/akshitaasaxena/python-ds/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dct={
    "name":["tom","nick","krish"],
    "age": [19,20,43],
    "city":[1,2,3]
}
pf=pd.DataFrame(dct,index=['a','b','c'])
print(pf)
display(pf)
# Out:
#     name  age  city
# a    tom   19     1
# b   nick   20     2
# c  krish   43     3
#     name  age  city
# a    tom   19     1
# b   nick   20     2
# c  krish   43     3

# %%
df=pd.read_csv("student_data.csv")
df.tail(3) #last ki 3 rows
df.shape #10000 rowws, 8 columns
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 9997                     10              37       95.94           Placed
# 9998                      8              52       88.61           Placed
# 9999                     16              52       78.96           Placed

# %% [markdown]
# df.info(): file ke baare me data dedega- saare nahi but thoda sa toh dega.
# for eg: column ke baare mein kuch info dediya etc.

# %%
df=pd.read_csv("student_data.csv")
df.info() #metadata deta(data about data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   study_hours            10000 non-null  int64
#  1   attendance             10000 non-null  int64
#  2   sleep_hours            10000 non-null  int64
#  3   internet_usage         10000 non-null  int64
#  4   assignments_completed  10000 non-null  int64
#  5   previous_score         10000 non-null  int64
#  6   exam_score             10000 non-null  float64
#  7   placement_status       10000 non-null  object
# dtypes: float64(1), int64(6), object(1)
# memory usage: 625.1+ KB

# %% [markdown]
# The describe() method in pandas generates quick descriptive statistics to summarize the central tendency, dispersion, and shape of a dataset's distribution.

# %%
df.describe()
# Out:
#         study_hours   attendance   sleep_hours  internet_usage  \
# count  10000.000000  10000.00000  10000.000000    10000.000000
# mean       5.989600     69.88460      6.498500        6.062600
# std        3.163589     17.61653      1.709354        3.138163
# min        1.000000     40.00000      4.000000        1.000000
# 25%        3.000000     55.00000      5.000000        3.000000
# 50%        6.000000     70.00000      6.500000        6.000000
# 75%        9.000000     85.00000      8.000000        9.000000
# max       11.000000    100.00000      9.000000       11.000000
#
#        assignments_completed  previous_score    exam_score
# count           10000.000000     10000.00000  10000.000000
# mean                9.988400        64.91100     86.704207
# std                 6.034145        17.50302     15.058383
# min                 0.000000        35.00000     26.670000
# 25%                 5.000000        50.00000     76.727500
# ...

# %% [markdown]
# interquartile range,
# quartile

# %%
df.columns #returns all columns
df.index #display row index labels
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
#df['study_hours','internet_usage']
df['study_hours'] # will return a column
df[['study_hours','internet_usage']]
df.study_hours # can be used to acces data, but not recommended, can give errors as well
# Out:
#       study_hours  internet_usage
# 0               7               7
# 1               4               3
# 2              11               6
# 3               8               8
# 4               5               6
# ...           ...             ...
# 9995            2               7
# 9996            7               9
# 9997           10               5
# 9998           10               5
# 9999            2              11
#
# [10000 rows x 2 columns]

# %%
df.iloc[0] # 0th row ke saare columns return krra hai.
df.iloc[0:5] #0 se 5 tak ke rows return krra hai.
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed

# %%
df.loc[df['study_hours']==11] #jaha studyhours are 11
df.loc[df['study_hours']==11,['sleep_hours']]
# we can get the column we want , like here, we will get: sleephours of students whose studyhours is 11
df.loc[df['study_hours']==11,['sleep_hours','assignments_completed','study_hours']].iloc[4:8]
# we can get the column we want , like here, we will get: sleephours,assignments_completed,study hours of students whose studyhours is 11
# Out:
#       sleep_hours  assignments_completed  study_hours
# 2               7                     10           11
# 9               4                     15           11
# 10              8                     12           11
# 29              9                      1           11
# 30              5                      4           11
# ...           ...                    ...          ...
# 9969            8                      3           11
# 9971            9                      0           11
# 9978            8                     16           11
# 9979            9                     18           11
# 9988            6                      6           11
#
# [868 rows x 3 columns]

# %% [markdown]
# filter rows where study_hours is equal to 11.
# From those filtered rows, select only the columns:
# sleep_hours
# assignments_completed
# study_hours:df.loc[df['study_hours']==11,['sleep_hours','assignments_completed','study_hours']].iloc[4:8]

# %%
df2=df.loc[df['sleep_hours']==11] # ye bas ek condition hai
df2[['study_hours']]
# Out:
# Empty DataFrame
# Columns: [study_hours]
# Index: []

# %%
df.loc[df["assignments_completed"]==8].iloc[1]
# Out:
# study_hours                   5
# attendance                   52
# sleep_hours                   8
# internet_usage                6
# assignments_completed         8
# previous_score               40
# exam_score                78.82
# placement_status         Placed
# Name: 4, dtype: object

# %%
df[df["assignments_completed"]>3]
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %% [markdown]
# ![newfilter.png](data:image/png;base64,...)

# %%
df["age"]=20 # add column named age
#rename columns
df.rename(columns={'assignments_completed':'assign_completed'}) #returns a new dataframe, new created.
df.rename(columns={'assignments_completed':'assign_completed'},inplace=True) # makes changes in the original dataframe, doesnot create new
display(df)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
df.drop("assign_completed",axis=1)
df.dropna()
df.sort_values("attendance")
df.sort_index()
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  assign_completed  \
# 0               7          56            8               7                10
# 1               4          69            5               3                 8
# 2              11          60            7               6                10
# 3               8          99            9               8                 4
# 4               5          52            8               6                 8
# ...           ...         ...          ...             ...               ...
# 9995            2          58            9               7                 8
# 9996            7          98            6               9                 4
# 9997           10          44            8               5                10
# 9998           10          75            7               5                 8
# 9999            2          70            6              11                16
#
# ...

# %%
dict={
    "name":["akshita","jiya","aman"],
    "age":[12,23,78],
    "hobby":["abc","dfg",None]

}
df1=pd.DataFrame(dict)
df1.dropna()
#how to use lambda function inside sort
# Out:
#       name  age hobby
# 0  akshita   12   abc
# 1     jiya   23   dfg

# %%
#check for missing values
df1.isnull()

#check for non-missing values
df1.notnull()

# replace missing values
df1.fillna(4)# nayi return krega, purani me changes nahi krega
# Out:
#       name  age hobby
# 0  akshita   12   abc
# 1     jiya   23   dfg
# 2     aman   78     4

# %%
#unique
df["attendance"].unique()
